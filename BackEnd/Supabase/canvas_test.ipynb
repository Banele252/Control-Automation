# %% [markdown]
# Testing supabase link

# %% [markdown]
# import libraries

# %%
from supabase import create_client, Client
import os
from dotenv import load_dotenv

# %% [markdown]
# assign the key and url

# %%
SUPABASE_KEY = os.getenv("SUPABASE_KEY")
SUPABASE_URL = os.getenv("SUPABASE_URL")

# %% [markdown]
# assign supabase client

# %%
# Create Supabase client
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

# %%
response = supabase.table('test_data').select("*").execute()
data = response.data

# %% [markdown]
# the data was successfully retrieved

# %%
type(data)
# Out:
# list

# %%
print(data)
import pandas
# Out:
# [{'index': 1, 'country': 'India', 'country_code': 'IND', 'continent': 'Asia', 'population': 1380004385, 'indicator': 'confirmed cases', 'daily_count': '0', 'date': '2020/01/02', 'rate_14_day': None, 'source': 'Epidemic intelligence, national daily data'}, {'index': 2, 'country': 'India', 'country_code': 'IND', 'continent': 'Asia', 'population': 1380004385, 'indicator': 'confirmed cases', 'daily_count': '0', 'date': '2020/01/03', 'rate_14_day': None, 'source': 'Epidemic intelligence, national daily data'}, {'index': 3, 'country': 'India', 'country_code': 'IND', 'continent': 'Asia', 'population': 1380004385, 'indicator': 'confirmed cases', 'daily_count': '0', 'date': '2020/01/04', 'rate_14_day': None, 'source': 'Epidemic intelligence, national daily data'}, {'index': 4, 'country': 'India', 'country_code': 'IND', 'continent': 'Asia', 'population': 1380004385, 'indicator': 'confirmed cases', 'daily_count': '0', 'date': '2020/01/05', 'rate_14_day': None, 'source': 'Epidemic intelligence, 
# ...

# %% [markdown]
# Extract the data keys and values in a dictionary, make the keys the field names and the values to be field values (The test was successful)

# %%
import pandas as pd

# %%
# type(data[0]) -- This is a dictionary 

# print(data[0].values()) we can extract values 


column_values = []

column_names = [key for key in data[0].keys()]

for i in range(len(data)):
    single_record = []
    single_record = [value for value in data[i].values()]
    column_values.append(single_record)

# %%
df = pd.DataFrame(data=column_values, columns=column_names)
df = df.reset_index(drop=True)

# %%
df.head(n=20)
# Out:
#     index country country_code continent  population        indicator  \
# 0       1   India          IND      Asia  1380004385  confirmed cases
# 1       2   India          IND      Asia  1380004385  confirmed cases
# 2       3   India          IND      Asia  1380004385  confirmed cases
# 3       4   India          IND      Asia  1380004385  confirmed cases
# 4       5   India          IND      Asia  1380004385  confirmed cases
# 5       6   India          IND      Asia  1380004385  confirmed cases
# 6       7   India          IND      Asia  1380004385  confirmed cases
# 7       8   India          IND      Asia  1380004385  confirmed cases
# 8       9   India          IND      Asia  1380004385  confirmed cases
# 9      10   India          IND      Asia  1380004385  confirmed cases
# 10     11   India          IND      Asia  1380004385  confirmed cases
# 11     12   India          IND      Asia  1380004385  confirmed cases
# ...

# %% [markdown]
# If I was planning not to use the wrapper

# %%
"""
import requests

SUPABASE_URL = "https://your-project.supabase.co"
SUPABASE_KEY = "your-anon-key"  # or service_role key for admin access

headers = {
    "apikey": SUPABASE_KEY,
    "Authorization": f"Bearer {SUPABASE_KEY}",
    "Content-Type": "application/json"
}

Get all rows

response = requests.get(
    f"{SUPABASE_URL}/rest/v1/your_table",
    headers=headers
)
data = response.json()

selecting specific rows

response = requests.get(
    f"{SUPABASE_URL}/rest/v1/your_table?select=id,name,email",
    headers=headers
)

performing multiple conditions

# Equal to
response = requests.get(
    f"{SUPABASE_URL}/rest/v1/your_table?status=eq.active",
    headers=headers
)

# Greater than or equal
response = requests.get(
    f"{SUPABASE_URL}/rest/v1/your_table?age=gte.18",
    headers=headers
)

# Multiple filters (AND)
response = requests.get(
    f"{SUPABASE_URL}/rest/v1/your_table?status=eq.active&age=gte.18",
    headers=headers
)
....
"""
